# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
1.0 0.753
1.1 0.760
1.2 0.785
1.3 0.694
1.4 0.689
1.5 0.479
1.6 0.479
1.7 0.690
1.8 0.788
1.9 0.554

# %%
plt.plot([0.8895900024492138, 0.760, 0.785, 0.694, 0.689, 0.479])
plt.ylabel('Order Parameter')
plt.xlabel('Temperature')
plt.title('Nematic Order Parameter vs T')
plt.show()

# %%
fig.suptitle('No axes on this figure')
# Out:
# Text(0.5, 0.98, 'No axes on this figure')
