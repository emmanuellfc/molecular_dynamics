# %% [markdown]
# # Nematic Order Parameter vs Temperature

# %%
data = [(1.0,0.753),(1.1,0.760),(1.2,0.785),(1.3,0.694),(1.4,0.689),(1.5,0.479),(1.6,0.479),(1.7,0.690),(1.8,0.788),(1.9,0.554)]

# %%
g1 = list_plot(data, marker='D', axes_labels=[r"$T$", r"$P_{2}$"])
g1
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
g2 = line(data, color='red')
g2
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
g1 + g2
# Out:
# Graphics object consisting of 2 graphics primitives

# %%
(g1+g2).save("plot_Order_parameter_vs_T.png", 
             gridlines=True, aspect_ratio=1, title='Order Parameter vs T')
