# %% [markdown]
# # Nematic Order Parameter vs Temperature

# %%
data = [(1.0,0.9216361525111821),
        (1.1,0.8761320556633652),
        (1.2,0.0),
        (1.3,0.0),
        (1.4,0.0),
        (1.5,0.0),
        (1.6,0.0),
        (1.7,0.0),
        (1.8,0.0),
        (1.9,0.0)]

# %%
g1 = list_plot(data, marker='D', axes_labels = [r"$T$", r"$P(\theta)_{2}$"], gridlines = True, aspect_ratio = 1.5)
g1
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
g2 = line(data, color='green')
g2
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
g1 + g2
# Out:
# Graphics object consisting of 2 graphics primitives

# %%
(g1+g2).save("plot_Order_parameter_vs_T.png", 
             gridlines=True, aspect_ratio=1, title='Order Parameter vs T')

# %%
rho = 1000 / 11358.16519
rho
# Out:
# 0.0880423891774724
